# %% [markdown]
# Импорт библиотеки pandas для работы с данными.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# С помощью pandas считываем csv файл, с которым мы будем взаимодействовать в качестве датафрейма, после чего выводим датафрейм для просмотра его столбцов или проверки целостности отображения.

# %%
df = pd.read_csv('/ds_salaries.csv')
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# Вывод пропущенных значений на весь датасет.

# %%
df.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# Вывод уникальных значений для столбца уровень опыта.

# %%
df.experience_level.unique()
# Out:
# array(['SE', 'MI', 'EN', 'EX'], dtype=object)

# %% [markdown]
# Вывод количества всех уникальных значений в датафрейме.

# %%
df.nunique()
# Out:
# work_year                4
# experience_level         4
# employment_type          4
# job_title               93
# salary                 815
# salary_currency         20
# salary_in_usd         1035
# employee_residence      78
# remote_ratio             3
# company_location        72
# company_size             3
# dtype: int64

# %% [markdown]
# Гистограмма по заработной плате.

# %%
fig, ax = plt.subplots()
ax.plot(df['salary'], df['experience_level'], linestyle='', marker='o')
ax.set_xlabel("salary")
ax.set_ylabel("experience_level")
# Out:
# Text(0, 0.5, 'experience_level')

# %%
df.boxplot('salary')
# Out:
# <Axes: >

# %% [markdown]
# Гистограмма по годам, когда была выплачена заработная плата.

# %%
df.hist(column='work_year')
# Out:
# array([[<Axes: title={'center': 'work_year'}>]], dtype=object)

# %% [markdown]
# Гистограмма по выплаченной заработной плате в USD.

# %%
df.hist(column='salary_in_usd')
# Out:
# array([[<Axes: title={'center': 'salary_in_usd'}>]], dtype=object)

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# Производим SELECT, выбираем только 3 столбца и вывеодим их.

# %%
df[["experience_level", "job_title", "salary_in_usd"]]
# Out:
#      experience_level                 job_title  salary_in_usd
# 0                  SE  Principal Data Scientist          85847
# 1                  MI               ML Engineer          30000
# 2                  MI               ML Engineer          25500
# 3                  SE            Data Scientist         175000
# 4                  SE            Data Scientist         120000
# ...               ...                       ...            ...
# 3750               SE            Data Scientist         412000
# 3751               MI  Principal Data Scientist         151000
# 3752               EN            Data Scientist         105000
# 3753               EN     Business Data Analyst         100000
# 3754               SE      Data Science Manager          94665
#
# [3755 rows x 3 columns]

# %% [markdown]
# Здесь мы отобразили все столбцы датафрейма и вывели примерную заработную плату в RUB.

# %%
df.assign(salary_in_rub=df["salary_in_usd"] * 100)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# Фильтрация по заработной плате в USD, которая больше 100000.

# %%
df[df["salary_in_usd"] > 100000]
# Out:
#       work_year experience_level employment_type  \
# 3          2023               SE              FT
# 4          2023               SE              FT
# 5          2023               SE              FT
# 6          2023               SE              FT
# 7          2023               SE              FT
# ...         ...              ...             ...
# 3747       2021               MI              FT
# 3749       2021               SE              FT
# 3750       2020               SE              FT
# 3751       2021               MI              FT
# 3752       2020               EN              FT
#
#                                job_title  salary salary_currency  \
# 3                         Data Scientist  175000             USD
# 4                         Data Scientist  120000             USD
# 5                      Applied Scientist  222200             USD
# 6                      Applied Scientist  136000             USD
# ...

# %% [markdown]
#  Выбираем значения определенной должности, количество упоминаний этой должности во всем датасете. Далее выводим датасет только с этой должностью.

# %%
BEP = df["job_title"] == "Data Scientist"
BEP.value_counts()
df[BEP]
# Out:
#       work_year experience_level employment_type       job_title  salary  \
# 3          2023               SE              FT  Data Scientist  175000
# 4          2023               SE              FT  Data Scientist  120000
# 7          2023               SE              FT  Data Scientist  219000
# 8          2023               SE              FT  Data Scientist  141000
# 9          2023               SE              FT  Data Scientist  147100
# ...         ...              ...             ...             ...     ...
# 3741       2020               MI              FT  Data Scientist  118000
# 3742       2020               MI              FT  Data Scientist  138350
# 3746       2021               MI              FT  Data Scientist  160000
# 3750       2020               SE              FT  Data Scientist  412000
# 3752       2020               EN              FT  Data Scientist  105000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %% [markdown]
# Выводим все штаб-квартиры работодателя, которые находятся в US, с заработной платой в USD больше 50000.

# %%
df[(df["company_location"] == "US") & (df["salary_in_usd"] > 50000)]
# Out:
#       work_year experience_level employment_type                 job_title  \
# 5          2023               SE              FT         Applied Scientist
# 6          2023               SE              FT         Applied Scientist
# 9          2023               SE              FT            Data Scientist
# 10         2023               SE              FT            Data Scientist
# 11         2023               SE              FT              Data Analyst
# ...         ...              ...             ...                       ...
# 3749       2021               SE              FT           Data Specialist
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
#
# ...

# %% [markdown]
# Аггрегация с помощью describe по колонке с заработной платой.

# %%
df.salary.describe()
# Out:
# count    3.755000e+03
# mean     1.906956e+05
# std      6.716765e+05
# min      6.000000e+03
# 25%      1.000000e+05
# 50%      1.380000e+05
# 75%      1.800000e+05
# max      3.040000e+07
# Name: salary, dtype: float64

# %% [markdown]
# Нахождение максимального значения в столбце с заработной платой в USD.

# %%
df.salary_in_usd.max()
# Out:
# 450000

# %% [markdown]
# Группировка по должности и нахождение среднего значения по всем строкам.

# %%
df.groupby('job_title').mean()
# Out:
# <ipython-input-20-5cca38d06f18>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('job_title').mean()
#                                  work_year         salary  salary_in_usd  \
# job_title
# 3D Computer Vision Researcher  2021.500000  120000.000000   21352.250000
# AI Developer                   2022.727273  137181.818182  136666.090909
# AI Programmer                  2022.500000   55000.000000   55000.000000
# AI Scientist                   2021.687500  275312.500000  110120.875000
# Analytics Engineer             2022.446602  151352.621359  152368.631068
# ...                                    ...            ...            ...
# Research Engineer              2022.864865  162752.810811  163108.378378
# Research Scientist             2022.500000  160768.890244  161214.195122
# ...

# %% [markdown]
# Группировка по уровню опыта с подсчетом их количества.

# %%
df.groupby("experience_level").size()
# Out:
# experience_level
# EN     320
# EX     114
# MI     805
# SE    2516
# dtype: int64

# %%
df1 = df[["job_title", "salary"]]
df1 = df1.sort_values(by='salary', ascending=False)
df1 = df1.head(10)
df1
# Out:
#                            job_title    salary
# 3669                  Data Scientist  30400000
# 3646                  Data Scientist  11000000
# 3574                 BI Data Analyst  11000000
# 3475                     ML Engineer   8500000
# 2966  Lead Machine Learning Engineer   7500000
# 3754            Data Science Manager   7000000
# 3476                     ML Engineer   7000000
# 2358                  Data Scientist   6600000
# 3192        Head of Machine Learning   6000000
# 1462            Head of Data Science   5000000
